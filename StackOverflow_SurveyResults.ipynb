# %%
# !pip install opendatasets --upgrade --

# %%
import pandas as pd

# %%
survey_public = pd.read_csv("C:\\Users\\jeeld\\OneDrive\\Desktop\\Canada\\PERSONAL_PROJECTS\\Case_Study\\survey_results_public.csv")

# %%
survey_public
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64456       64858                                                NaN      Yes
# 64457       64867                                                NaN      Yes
# 64458       64898                                                NaN      Yes
# 64459       64925                                                NaN      Yes
# 64460       65112                                                NaN      Yes
#
# ...

# %%
survey_schema = pd.read_csv("C:\\Users\\jeeld\\OneDrive\\Desktop\\Canada\\PERSONAL_PROJECTS\\Case_Study\\survey_results_schema.csv",index_col = 'Column').QuestionText

# %%
survey_schema
# Out:
# Column
# Respondent            Randomized respondent ID number (not in order ...
# MainBranch            Which of the following options best describes ...
# Hobbyist                                        Do you code as a hobby?
# Age                   What is your age (in years)? If you prefer not...
# Age1stCode            At what age did you write your first line of c...
#                                             ...
# WebframeWorkedWith    Which web frameworks have you done extensive d...
# WelcomeChange         Compared to last year, how welcome do you feel...
# WorkWeekHrs           On average, how many hours per week do you wor...
# YearsCode             Including any education, how many years have y...
# YearsCodePro          NOT including education, how many years have y...
# Name: QuestionText, Length: 61, dtype: object

# %%
survey_schema['Age']
# Out:
# 'What is your age (in years)? If you prefer not to answer, you may leave this question blank.'

# %%
selected_columns = [
    # Demographics
    'Country',
    'Age',
    'Gender',
    'EdLevel',
    'UndergradMajor',
    # Programming experience
    'Hobbyist',
    'Age1stCode',
    'YearsCode',
    'YearsCodePro',
    'LanguageWorkedWith',
    'LanguageDesireNextYear',
    'NEWLearn',
    'NEWStuck',
    # Employment
    'Employment',
    'DevType',
    'WorkWeekHrs',
    'JobSat',
    'JobFactors',
    'NEWOvertime',
    'NEWEdImpt'
]

# %%
# Creating a new variable survey_df which will select only the selected columns and simultaneously creating copy for that too
survey_public_df = survey_public[selected_columns].copy()

# %%
schema = survey_schema[selected_columns]

# %%
schema
# Out:
# Column
# Country                                                  Where do you live?
# Age                       What is your age (in years)? If you prefer not...
# Gender                    Which of the following describe you, if any? P...
# EdLevel                   Which of the following best describes the high...
# UndergradMajor                        What was your primary field of study?
# Hobbyist                                            Do you code as a hobby?
# Age1stCode                At what age did you write your first line of c...
# YearsCode                 Including any education, how many years have y...
# YearsCodePro              NOT including education, how many years have y...
# LanguageWorkedWith        Which programming, scripting, and markup langu...
# LanguageDesireNextYear    Which programming, scripting, and markup langu...
# NEWLearn                  How frequently do you learn a new language or ...
# ...

# %%
survey_public_df
# Out:
#                   Country   Age Gender  \
# 0                 Germany   NaN    Man
# 1          United Kingdom   NaN    NaN
# 2      Russian Federation   NaN    NaN
# 3                 Albania  25.0    Man
# 4           United States  31.0    Man
# ...                   ...   ...    ...
# 64456       United States   NaN    NaN
# 64457             Morocco   NaN    NaN
# 64458            Viet Nam   NaN    NaN
# 64459              Poland   NaN    NaN
# 64460               Spain   NaN    NaN
#
#                                                EdLevel  \
# 0      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2                                                  NaN
# 3      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                ...
# 64456  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...

# %%
survey_public_df.shape
# Out:
# (64461, 20)

# %%
survey_public_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64461 entries, 0 to 64460
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country                 64072 non-null  object
#  1   Age                     45446 non-null  float64
#  2   Gender                  50557 non-null  object
#  3   EdLevel                 57431 non-null  object
#  4   UndergradMajor          50995 non-null  object
#  5   Hobbyist                64416 non-null  object
#  6   Age1stCode              57900 non-null  object
#  7   YearsCode               57684 non-null  object
#  8   YearsCodePro            46349 non-null  object
#  9   LanguageWorkedWith      57378 non-null  object
#  10  LanguageDesireNextYear  54113 non-null  object
#  11  NEWLearn                56156 non-null  object
#  12  NEWStuck                54983 non-null  object
#  13  Employment              63854 non-null  object
# ...

# %% [markdown]
# #### By observing the results of above it can be infered that only Age and WorkWeekHrs contains numeric values other then these contain some other values. The Non-Null column represents the values which are not null i.e. they contain some values

# %%
survey_public_df.Age1stCode.unique()
# Out:
# array(['13', '19', '15', '18', '16', '14', '12', '20', '42', '8', '25',
#        '22', '30', '17', '21', '10', '46', '9', '7', '11', '6', nan, '31',
#        '29', '5', 'Younger than 5 years', '28', '38', '23', '27', '41',
#        '24', '53', '26', '35', '32', '40', '33', '36', '54', '48', '56',
#        '45', '44', '34', 'Older than 85', '39', '51', '68', '50', '37',
#        '47', '43', '52', '85', '64', '55', '58', '49', '76', '72', '73',
#        '83', '63'], dtype=object)

# %% [markdown]
# ##### As we can se that there are some values which are not number like 'younger than 5 years' so replacing these values with NaN values or empty placeholder values and converting rest of them to numbers

# %%
survey_public_df['Age1stCode'] = pd.to_numeric(survey_public_df.Age1stCode, errors = 'coerce')
survey_public_df['YearsCode'] = pd.to_numeric(survey_public_df.YearsCode, errors = 'coerce')
survey_public_df['YearsCodePro'] = pd.to_numeric(survey_public_df.YearsCodePro, errors = 'coerce')

# %%
survey_public_df.describe()
# Out:
#                 Age    Age1stCode     YearsCode  YearsCodePro   WorkWeekHrs
# count  45446.000000  57473.000000  56784.000000  44133.000000  41151.000000
# mean      30.834111     15.476572     12.782051      8.869667     40.782174
# std        9.585392      5.114081      9.490657      7.759961     17.816383
# min        1.000000      5.000000      1.000000      1.000000      1.000000
# 25%       24.000000     12.000000      6.000000      3.000000     40.000000
# 50%       29.000000     15.000000     10.000000      6.000000     40.000000
# 75%       35.000000     18.000000     17.000000     12.000000     44.000000
# max      279.000000     85.000000     50.000000     50.000000    475.000000

# %% [markdown]
# ##### As you can see above that in the minimum age section it shows 1 as the minimum number. Practically, it is not possible  for an infant to do coding at this age. Moreover, the maximum age of coding is 279 which is also not possible. so the best way todeal with this is to delete such faulty rows for better results. Same with WorkweekHours as there are total 168 hours in a week and as per above data it is showing 475 hours.

# %%
survey_public_df.drop(survey_public_df[survey_public_df.Age < 10].index, inplace=True)
survey_public_df.drop(survey_public_df[survey_public_df.Age > 100].index, inplace=True)
survey_public_df.drop(survey_public_df[survey_public_df.WorkWeekHrs > 140].index, inplace=True)

# %%
# Taking a glance at Gender column

survey_public_df['Gender'].value_counts()
# Out:
# Man                                                            45895
# Woman                                                           3835
# Non-binary, genderqueer, or gender non-conforming                385
# Man;Non-binary, genderqueer, or gender non-conforming            121
# Woman;Non-binary, genderqueer, or gender non-conforming           92
# Woman;Man                                                         73
# Woman;Man;Non-binary, genderqueer, or gender non-conforming       25
# Name: Gender, dtype: int64

# %% [markdown]
# ##### By observing above data, the fourth entity is not proper as it can generate some problrms in giving proper output. so removing such values (replacing with empty values)

# %%
import numpy as np

# %%
survey_public_df.where(~(survey_public_df.Gender.str.contains(';', na=False)), np.nan, inplace=True)

# %%
survey_public_df['Gender'].value_counts()
# Out:
# Man                                                  45895
# Woman                                                 3835
# Non-binary, genderqueer, or gender non-conforming      385
# Name: Gender, dtype: int64

# %%
survey_public_df.sample(10)
# Out:
#               Country   Age Gender  \
# 43349           India   NaN    NaN
# 25250          Mexico  26.0  Woman
# 53146   United States  26.0    Man
# 57667   United States  29.0    Man
# 24980         Romania  35.0    Man
# 7187        Australia  25.0    Man
# 51595  United Kingdom  20.0    Man
# 41739     Netherlands   NaN    NaN
# 47884          Poland  31.0    Man
# 10631         Germany  36.0    Man
#
#                                                  EdLevel  \
# 43349                                                NaN
# 25250       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 53146       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 57667       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 24980       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 7187        Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 51595  Some college/university study without earning ...
# 41739  Secondary school (e.g. American high school, G...
# ...

# %%
survey_public_df.head(10)
# Out:
#               Country   Age Gender  \
# 0             Germany   NaN    Man
# 1      United Kingdom   NaN    NaN
# 2  Russian Federation   NaN    NaN
# 3             Albania  25.0    Man
# 4       United States  31.0    Man
# 5             Germany   NaN    Man
# 6               India   NaN    NaN
# 7       United States  36.0    Man
# 8             Tunisia  30.0    Man
# 9      United Kingdom  22.0    Man
#
#                                              EdLevel  \
# 0    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2                                                NaN
# 3    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 5  Secondary school (e.g. American high school, G...
# 6       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 7       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 8                 Professional degree (JD, MD, etc.)
# ...

# %% [markdown]
# # Exploratory Data Analysis and Visualisation

# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (9, 5)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %% [markdown]
# ## Country

# %%
survey_public_df.Country.nunique()
# Out:
# 183

# %%
survey_public_df['Country'].value_counts()
# Out:
# United States          12371
# India                   8364
# United Kingdom          3881
# Germany                 3864
# Canada                  2175
#                        ...
# Nauru                      1
# Lesotho                    1
# Saint Lucia                1
# Antigua and Barbuda        1
# Marshall Islands           1
# Name: Country, Length: 183, dtype: int64

# %%
top_countries = survey_public_df['Country'].value_counts().head(15)
top_countries
# Out:
# United States         12371
# India                  8364
# United Kingdom         3881
# Germany                3864
# Canada                 2175
# France                 1884
# Brazil                 1804
# Netherlands            1332
# Poland                 1259
# Australia              1199
# Spain                  1157
# Italy                  1115
# Russian Federation     1085
# Sweden                  879
# Pakistan                802
# Name: Country, dtype: int64

# %%
plt.figure(figsize = (12,6))
plt.xticks(rotation = 75)
plt.title(schema.Country)
sns.barplot(x = top_countries.index, y = top_countries);

# %% [markdown]
# ## Age

# %%
plt.figure(figsize=(12, 6))
plt.title(schema.Age)
plt.xlabel('Age')
plt.ylabel('Number of respondents')

plt.hist(survey_public_df.Age, bins=np.arange(10,80,5), color='purple');

# %% [markdown]
# ## Gender

# %%
gender_counts = survey_public_df['Gender'].value_counts()
gender_counts
# Out:
# Man                                                  45895
# Woman                                                 3835
# Non-binary, genderqueer, or gender non-conforming      385
# Name: Gender, dtype: int64

# %%
plt.figure(figsize = (12,6))
plt.title(schema.Gender)
plt.pie(gender_counts, labels = gender_counts.index, autopct='%1.1f%%', startangle=180);

# %% [markdown]
# ## Education Level

# %%
survey_public_df['EdLevel'].value_counts(normalize = True) * 100
# Out:
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                          46.254014
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                       22.856742
# Some college/university study without earning a degree                                12.570857
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)     8.290483
# Associate degree (A.A., A.S., etc.)                                                    3.213352
# Other doctoral degree (Ph.D., Ed.D., etc.)                                             2.950106
# Primary/elementary school                                                              1.630368
# Professional degree (JD, MD, etc.)                                                     1.391692
# I never completed any formal education                                                 0.842386
# Name: EdLevel, dtype: float64

# %%
percent = survey_public_df['EdLevel'].value_counts(normalize = True) * 100
sns.barplot(x=percent, y=percent.index)
plt.xticks(rotation=75);
plt.title(schema['EdLevel'])
plt.ylabel(None);

# %%
undergrad_pct = survey_public_df.UndergradMajor.value_counts() * 100 / survey_public_df.UndergradMajor.count()

sns.barplot(x=undergrad_pct, y=undergrad_pct.index)

plt.title(schema.UndergradMajor)
plt.ylabel(None);
plt.xlabel('Percentage');

# %% [markdown]
# ## Employment

# %%
schema.Employment
# Out:
# 'Which of the following best describes your current employment status?'

# %%
(survey_public_df.Employment.value_counts(normalize=True, ascending=True)*100).plot(kind='barh', color='g')
plt.title(schema.Employment)
plt.xlabel('Percentage');

# %%
schema.DevType
# Out:
# 'Which of the following describe you? Please select all that apply.'

# %%
survey_public_df['DevType'].value_counts()
# Out:
# Developer, full-stack                                                                                                                                                           4396
# Developer, back-end                                                                                                                                                             3056
# Developer, back-end;Developer, front-end;Developer, full-stack                                                                                                                  2214
# Developer, back-end;Developer, full-stack                                                                                                                                       1465
# Developer, front-end                                                                                                                                                            1390
# ...

# %% [markdown]
# ##### From above data it is clear that there are multiple options which are given to users to selcect the developer type.

# %%
# The following lines of code will split the multiple data in a column to 

def split_multicolumn(col_series):
    result_df = col_series.to_frame()
    options = []
    # Iterate over the column
    for idx, value  in col_series[col_series.notnull()].iteritems():
        # Break each value into list of options
        for option in value.split(';'):
            # Add the option as a column to result
            if not option in result_df.columns:
                options.append(option)
                result_df[option] = False
            # Mark the value in the option column as True
            result_df.at[idx, option] = True
    return result_df[options]

# %%
DevType_df = split_multicolumn(survey_public_df.DevType)

# %%
DevType_df
# Out:
#        Developer, desktop or enterprise applications  Developer, full-stack  \
# 0                                               True                   True
# 1                                              False                   True
# 2                                              False                  False
# 3                                              False                  False
# 4                                              False                  False
# ...                                              ...                    ...
# 64456                                          False                  False
# 64457                                          False                  False
# 64458                                          False                  False
# 64459                                          False                  False
# 64460                                          False                  False
#
# ...

# %%
DevType_totals = DevType_df.sum().sort_values(ascending = False)
DevType_totals
# Out:
# Developer, back-end                              26996
# Developer, full-stack                            26915
# Developer, front-end                             18128
# Developer, desktop or enterprise applications    11687
# Developer, mobile                                 9406
# DevOps specialist                                 5915
# Database administrator                            5658
# Designer                                          5262
# System administrator                              5185
# Developer, embedded applications or devices       4701
# Data or business analyst                          3970
# Data scientist or machine learning specialist     3939
# Developer, QA or test                             3893
# Engineer, data                                    3700
# Academic researcher                               3502
# Educator                                          2895
# Developer, game or graphics                       2751
# ...

# %% [markdown]
# # Asking and answering questions

# %% [markdown]
# ### Q Which is the popular language of 2020 ?

# %%
survey_public_df.LanguageWorkedWith
# Out:
# 0                                   C#;HTML/CSS;JavaScript
# 1                                         JavaScript;Swift
# 2                                 Objective-C;Python;Swift
# 3                                                      NaN
# 4                                        HTML/CSS;Ruby;SQL
#                                ...
# 64456                                                  NaN
# 64457    Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# 64458                                                  NaN
# 64459                                             HTML/CSS
# 64460                      C#;HTML/CSS;Java;JavaScript;SQL
# Name: LanguageWorkedWith, Length: 64306, dtype: object

# %%
Language_df = split_multicolumn(survey_public_df.LanguageWorkedWith)
Language_df
# Out:
#           C#  HTML/CSS  JavaScript  Swift  Objective-C  Python   Ruby    SQL  \
# 0       True      True        True  False        False   False  False  False
# 1      False     False        True   True        False   False  False  False
# 2      False     False       False   True         True    True  False  False
# 3      False     False       False  False        False   False  False  False
# 4      False      True       False  False        False   False   True   True
# ...      ...       ...         ...    ...          ...     ...    ...    ...
# 64456  False     False       False  False        False   False  False  False
# 64457   True      True        True   True         True    True   True   True
# 64458  False     False       False  False        False   False  False  False
# 64459  False      True       False  False        False   False  False  False
# 64460   True      True        True  False        False   False  False   True
#
# ...

# %%
Language_percentage = Language_df.mean().sort_values(ascending = False) * 100
Language_percentage
# Out:
# JavaScript               59.893323
# HTML/CSS                 55.801947
# SQL                      48.444935
# Python                   39.001026
# Java                     35.618760
# Bash/Shell/PowerShell    29.239884
# C#                       27.803004
# PHP                      23.130035
# TypeScript               22.461357
# C++                      21.114670
# C                        19.236152
# Go                        7.758219
# Kotlin                    6.887382
# Ruby                      6.229590
# Assembly                  5.447392
# VBA                       5.394520
# Swift                     5.226573
# R                         5.064846
# Rust                      4.498803
# Objective-C               3.603085
# Dart                      3.517557
# Scala                     3.150561
# Perl                      2.757130
# Haskell                   1.861413
# Julia                     0.782198
# dtype: float64

# %%
plt.figure(figsize = (12,12))
sns.barplot(x = Language_percentage, y = Language_percentage.index)
plt.xlabel('count')
plt.title('Languages used in past year');

# %% [markdown]
# From above visualisation it can be inferred that the most famous language back then was Javascript followed by HTML/CSS. Hence web development was area of intrest for most of the people. Followed by that is the SQL as it is easy to learn and understand. surprisingly, python beat java. This is surprising as Java is famous for performing both server side coding and application development

# %% [markdown]
# ### Q) Which languages are people intrested to learn over the coming years

# %%
language_interested_df = split_multicolumn(survey_public_df.LanguageDesireNextYear)
language_interested_percentage = language_interested_df.mean().sort_values(ascending = False) * 100
language_interested_percentage
# Out:
# Python                   41.143906
# JavaScript               40.425466
# HTML/CSS                 32.028116
# SQL                      30.799614
# TypeScript               26.451653
# C#                       21.058688
# Java                     20.464653
# Go                       19.432090
# Bash/Shell/PowerShell    18.057413
# Rust                     16.270643
# C++                      15.014151
# Kotlin                   14.760676
# PHP                      10.947657
# C                         9.359935
# Swift                     8.692812
# Dart                      7.308805
# R                         6.571704
# Ruby                      6.425528
# Scala                     5.326097
# Haskell                   4.593662
# Assembly                  3.766367
# Julia                     2.540976
# Objective-C               2.338818
# Perl                      1.761888
# VBA                       1.611047
# dtype: float64

# %%
plt.figure(figsize=(12, 12))
sns.barplot(x=language_interested_percentage, y=language_interested_percentage.index)
plt.title("Languages people are intersted in learning over the next year");
plt.xlabel('count');

# %% [markdown]
# Unsurprisingly, Python tops the position among all the programming languages. since it is easy to learn and used for doing multiple things like in data analysis, used in machine learning, big data, cloud computing, numerical analysis and many more.

# %% [markdown]
# ### Q) Which language is the most loved language ? i.e. what percentage of people have language they worked with and the language they want to work have in common ?

# %%
language_loved_df = Language_df & language_interested_df

# %%
language_loved_percentages = (language_loved_df.sum() * 100/ Language_df.sum()).sort_values(ascending=False)
# Out:
# Rust                     86.069824
# TypeScript               67.114373
# Python                   66.598884
# Kotlin                   62.813276
# Go                       62.176789
# Dart                     62.068966
# Julia                    61.431412
# C#                       59.623021
# Swift                    59.476346
# JavaScript               58.353888
# SQL                      56.607710
# Bash/Shell/PowerShell    53.688241
# HTML/CSS                 53.494594
# Scala                    53.257651
# Haskell                  51.378446
# R                        44.427387
# Java                     44.108273
# C++                      43.415820
# Ruby                     42.735896
# PHP                      37.232755
# C                        32.983023
# Assembly                 29.089352
# Perl                     28.369994
# Objective-C              23.133362
# VBA                      19.458057
# dtype: float64

# %%
plt.figure(figsize=(12, 12))
sns.barplot(x=language_loved_percentages, y=language_loved_percentages.index)
plt.title("Most loved languages");
plt.xlabel('count');

# %% [markdown]
# For four years running, Rust has been the most popular language on StackOverflow. The second-most common language is TypeScript, a well-liked JavaScript substitute for web development.
#
# Despite being one of the most commonly used languages in the world, Python appears at number three. In addition to having a strong foundation and being simple to learn and use, Python boasts a sizable ecosystem of industry-specific libraries and a sizable global community.

# %% [markdown]
# ### Q) Which language is the most dreaded language ?

# %%
language_dread_df = Language_df & ~language_interested_df

# %%
language_dread_percentages = (language_dread_df.sum() * 100/ Language_df.sum()).sort_values(ascending=False)
language_dread_percentages
# Out:
# VBA                      80.541943
# Objective-C              76.866638
# Perl                     71.630006
# Assembly                 70.910648
# C                        67.016977
# PHP                      62.767245
# Ruby                     57.264104
# C++                      56.584180
# Java                     55.891727
# R                        55.572613
# Haskell                  48.621554
# Scala                    46.742349
# HTML/CSS                 46.505406
# Bash/Shell/PowerShell    46.311759
# SQL                      43.392290
# JavaScript               41.646112
# Swift                    40.523654
# C#                       40.376979
# Julia                    38.568588
# Dart                     37.931034
# Go                       37.823211
# Kotlin                   37.186724
# Python                   33.401116
# TypeScript               32.885627
# Rust                     13.930176
# dtype: float64

# %%
plt.figure(figsize=(12, 12))
sns.barplot(x=language_dread_percentages, y=language_dread_percentages.index)
plt.title("Most dread languages");
plt.xlabel('count');

# %% [markdown]
# ### Q) How important is to start coding at an early age?

# %%
schema.YearsCodePro
# Out:
# 'NOT including education, how many years have you coded professionally (as a part of your work)?'

# %%
sns.scatterplot(x='Age', y='YearsCodePro', hue='Hobbyist', data=survey_public_df)
plt.xlabel("Age")
plt.ylabel("Years of professional coding experience");

# %% [markdown]
# It is observed that points are all over the place. so, it can be inferred that there is no particular age of starting coding you can start at any age. It just requires interest and dedication towards coding

# %%
plt.title(schema.Age1stCode)
sns.histplot(x=survey_public_df.Age1stCode, bins=30, kde=True);

# %%
_
